# %% [markdown]
# #机器学习中必备的库
# 1) Scikit-learn: Includes various machine learning algorthms.
# 2) Numpy: Basic pack that inlcudes multi-dimension arrays and functions
# 3) SciPy: Basic pack that includes matrix and functions
# 4) matplotlib: Basic pack that includes lots of plots.
# 5) pandas: Basic pack that could interact with database.

# %%
# How to view your version of Python and any package
import sys
print("Python version: {}".format(sys.version))
# Out:
# Python version: 3.12.3 (v3.12.3:f6650f9ad7, Apr  9 2024, 08:18:48) [Clang 13.0.0 (clang-1300.0.29.30)]

# %%
import pandas as pd
print("pandas version: {}".format(pd.__version__))
# Out:
# pandas version: 2.3.3

# %% [markdown]
# # Train-test split
# 准备一组数据（带标签数据），分成训练数据和测试数据两组。在scikit-learn中这个组分别是75%-25%。训练模型，然后rollout到更大的数据集上。
# 在scikit-learn中数据通常用大写的X表示而标签用小写的y表示。
# Train-test split会产生 X_train, X_test, y_train, y_test 四个变量。

# %%
# Train-test split的代码, train_test_split 函数默认把75%作为train，25%作为test。
# random_state是生成随机数列表的种子。
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    iris_dataset['data'], iris_dataset['target'], random_state=0
)

# %% [markdown]
# # 观察数据
# 可以用pandas中的scatter matrix来创建一个矩阵图。观察数据的特征后再判断这个数据是否是一组很好的能够机器学习的数据。
